# %% [markdown]
# # Short (sampled) multilingual dataset creation
#
# Concatenation of the monolingual subsampled datasets into one.

# %%
# !pip install datasets==2.11.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datasets==2.11.0 in /usr/local/lib/python3.10/dist-packages (2.11.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets==2.11.0) (1.22.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.11.0) (9.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.11.0) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets==2.11.0) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.11.0) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.11.0) (4.65.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets==2.11.0) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets==2.11.0) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.11.0) (2023.4.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets==2.11.0) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.11.0) (0.14.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets==2.11.0) (23.1)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from datasets==2.11.0) (0.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.11.0) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.11.0) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.11.0) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.11.0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.11.0) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.11.0) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.11.0) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.11.0) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets==2.11.0) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets==2.11.0) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.11.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.11.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.11.0) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.11.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.11.0) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets==2.11.0) (1.16.0)

# %% [markdown]
# ## Data Download

# %%
from datasets import load_dataset, interleave_datasets

# %% [markdown]
# We use our own created datasets with paraphrases.

# %%
raw_ds_en = load_dataset('yawnick/para_crawl_enen')  # change to english
raw_ds_de = load_dataset('yawnick/para_crawl_dede')
raw_ds_cz = load_dataset('yawnick/para_crawl_cscs')  # change to czech
raw_ds_sl = load_dataset('yawnick/para_crawl_slsl')  # change to slovene
# Out:
# WARNING:datasets.builder:Found cached dataset csv (/root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_enen-1825b56ac7ffdb28/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:datasets.builder:Found cached dataset csv (/root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_dede-33f67bdf41063882/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:datasets.builder:Found cached dataset csv (/root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_cscs-8346f3eb1e22ef37/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:datasets.builder:Found cached dataset csv (/root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_slsl-e1050e0a2fc9f827/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# Let's store the splits separately.

# %%
raw_ds_en_train = raw_ds_en['train']
raw_ds_en_val = raw_ds_en['validation']
raw_ds_en_test = raw_ds_en['test']
raw_ds_de_train = raw_ds_de['train']
raw_ds_de_val = raw_ds_de['validation']
raw_ds_de_test = raw_ds_de['test']
raw_ds_cz_train = raw_ds_cz['train']
raw_ds_cz_val = raw_ds_cz['validation']
raw_ds_cz_test = raw_ds_cz['test']
raw_ds_sl_train = raw_ds_sl['train']
raw_ds_sl_val = raw_ds_sl['validation']
raw_ds_sl_test = raw_ds_sl['test']

# %%
raw_ds_en_train, raw_ds_en_val, raw_ds_en_test
# Out:
# (Dataset({
#      features: ['Original', 'Paraphrase'],
#      num_rows: 55544
#  }),
#  Dataset({
#      features: ['Original', 'Paraphrase'],
#      num_rows: 9803
#  }),
#  Dataset({
#      features: ['Original', 'Paraphrase'],
#      num_rows: 11532
#  }))

# %% [markdown]
# First, we shuffle all datasets. The seed is important if we later want to continue training and use the same training and validation data.

# %%
seed = 3435

# %%
raw_ds_en_train = raw_ds_en_train.shuffle(seed=seed)
raw_ds_en_val = raw_ds_en_val.shuffle(seed=seed)
raw_ds_en_test = raw_ds_en_test.shuffle(seed=seed)

raw_ds_de_train = raw_ds_de_train.shuffle(seed=seed)
raw_ds_de_val = raw_ds_de_val.shuffle(seed=seed)
raw_ds_de_test = raw_ds_de_test.shuffle(seed=seed)

raw_ds_cz_train = raw_ds_cz_train.shuffle(seed=seed)
raw_ds_cz_val = raw_ds_cz_val.shuffle(seed=seed)
raw_ds_cz_test = raw_ds_cz_test.shuffle(seed=seed)

raw_ds_sl_train = raw_ds_sl_train.shuffle(seed=seed)
raw_ds_sl_val = raw_ds_sl_val.shuffle(seed=seed)
raw_ds_sl_test = raw_ds_sl_test.shuffle(seed=seed)
# Out:
# WARNING:datasets.arrow_dataset:Loading cached shuffled indices for dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_enen-1825b56ac7ffdb28/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-9832c78a1da91e73.arrow
# WARNING:datasets.arrow_dataset:Loading cached shuffled indices for dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_enen-1825b56ac7ffdb28/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-3352f4e7ea2e9701.arrow
# WARNING:datasets.arrow_dataset:Loading cached shuffled indices for dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_enen-1825b56ac7ffdb28/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-a897573f386226ca.arrow
# WARNING:datasets.arrow_dataset:Loading cached shuffled indices for dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_dede-33f67bdf41063882/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-b95277a1132386fa.arrow
# WARNING:datasets.arrow_dataset:Loading cached shuffled indices for dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_dede-33f67bdf41063882/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-c9d211daea801c65.arrow
# WARNING:datasets.arrow_dataset:Loading cached shuffled indices for dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_dede-33f67bdf41063882/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-d6b89f41e7de802b.arrow
# WARNING:datasets.arrow_dataset:Loading cached shuffled indices for dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_cscs-8346f3eb1e22ef37/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-30118f9e0598a442.arrow
# WARNING:datasets.arrow_dataset:Loading cached shuffled indices for dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_cscs-8346f3eb1e22ef37/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-dd7810e91286e76e.arrow
# WARNING:datasets.arrow_dataset:Loading cached shuffled indices for dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_cscs-8346f3eb1e22ef37/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-838e22cb1aaa54ec.arrow
# WARNING:datasets.arrow_dataset:Loading cached shuffled indices for dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_slsl-e1050e0a2fc9f827/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-4874d85f24b637ae.arrow
# WARNING:datasets.arrow_dataset:Loading cached shuffled indices for dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_slsl-e1050e0a2fc9f827/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-b71f700dbbbf015d.arrow
# WARNING:datasets.arrow_dataset:Loading cached shuffled indices for dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_slsl-e1050e0a2fc9f827/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-29c39a11e548960f.arrow

# %% [markdown]
# `flatten_indices()` is used to resolve/remove the index mapping created by `shuffle()`.

# %%
raw_ds_en_train = raw_ds_en_train.flatten_indices()
raw_ds_en_val = raw_ds_en_val.flatten_indices()
raw_ds_en_test = raw_ds_en_test.flatten_indices()

raw_ds_de_train = raw_ds_de_train.flatten_indices()
raw_ds_de_val = raw_ds_de_val.flatten_indices()
raw_ds_de_test = raw_ds_de_test.flatten_indices()

raw_ds_cz_train = raw_ds_cz_train.flatten_indices()
raw_ds_cz_val = raw_ds_cz_val.flatten_indices()
raw_ds_cz_test = raw_ds_cz_test.flatten_indices()

raw_ds_sl_train = raw_ds_sl_train.flatten_indices()
raw_ds_sl_val = raw_ds_sl_val.flatten_indices()
raw_ds_sl_test = raw_ds_sl_test.flatten_indices()
# Out:
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_enen-1825b56ac7ffdb28/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-b61c6a377f72975c.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_enen-1825b56ac7ffdb28/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-caec7cd62917732c.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_enen-1825b56ac7ffdb28/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-897261dba658d8a3.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_dede-33f67bdf41063882/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-954855a6e69112b7.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_dede-33f67bdf41063882/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-fa4f1d462b1965c8.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_dede-33f67bdf41063882/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-65e2378d1b2cd1c7.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_cscs-8346f3eb1e22ef37/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-c70bf7677c7e4acf.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_cscs-8346f3eb1e22ef37/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-abd37b5a84198b56.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_cscs-8346f3eb1e22ef37/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-2482c38add414188.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_slsl-e1050e0a2fc9f827/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-05861e425c8fd4eb.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_slsl-e1050e0a2fc9f827/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-492f5dbb5437aa97.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_slsl-e1050e0a2fc9f827/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-05b65242e40a0682.arrow

# %% [markdown]
# If we want to take one fourth of each dataset we do that here:

# %%
SUBSAMPLING_CONSTANT = 4

# %%
assert raw_ds_en_train.num_rows == raw_ds_de_train.num_rows == raw_ds_cz_train.num_rows == raw_ds_sl_train.num_rows
assert raw_ds_en_val.num_rows == raw_ds_de_val.num_rows == raw_ds_cz_val.num_rows == raw_ds_sl_val.num_rows
assert raw_ds_en_test.num_rows == raw_ds_de_test.num_rows == raw_ds_cz_test.num_rows == raw_ds_sl_test.num_rows

length_per_ds_train = raw_ds_en_train.num_rows // SUBSAMPLING_CONSTANT
length_per_ds_val = raw_ds_en_val.num_rows // SUBSAMPLING_CONSTANT
length_per_ds_test = raw_ds_en_test.num_rows // SUBSAMPLING_CONSTANT

print("PER LANGUAGE:")
print(f"  {raw_ds_en_train.num_rows=} -> {length_per_ds_train=}")
print(f"  {raw_ds_en_val.num_rows=} -> {length_per_ds_val=}")
print(f"  {raw_ds_en_test.num_rows=} -> {length_per_ds_test=}")

total_before = raw_ds_en_train.num_rows + raw_ds_en_val.num_rows + raw_ds_en_test.num_rows
total_after = length_per_ds_train + length_per_ds_val + length_per_ds_test
print(f"  {total_before=} {total_after=}")
# Out:
# PER LANGUAGE:
#   raw_ds_en_train.num_rows=55544 -> length_per_ds_train=13886
#   raw_ds_en_val.num_rows=9803 -> length_per_ds_val=2450
#   raw_ds_en_test.num_rows=11532 -> length_per_ds_test=2883
#   total_before=76879 total_after=19219

# %%
raw_ds_en_train = raw_ds_en_train.select(range(length_per_ds_train))
raw_ds_en_val = raw_ds_en_val.select(range(length_per_ds_val))
raw_ds_en_test = raw_ds_en_test.select(range(length_per_ds_test))

raw_ds_de_train = raw_ds_de_train.select(range(length_per_ds_train, length_per_ds_train * 2))
raw_ds_de_val = raw_ds_de_val.select(range(length_per_ds_val, length_per_ds_val * 2))
raw_ds_de_test = raw_ds_de_test.select(range(length_per_ds_test, length_per_ds_test * 2))

raw_ds_cz_train = raw_ds_cz_train.select(range(length_per_ds_train * 2, length_per_ds_train * 3))
raw_ds_cz_val = raw_ds_cz_val.select(range(length_per_ds_val * 2, length_per_ds_val * 3))
raw_ds_cz_test = raw_ds_cz_test.select(range(length_per_ds_test * 2, length_per_ds_test * 3))

raw_ds_sl_train = raw_ds_sl_train.select(range(length_per_ds_train * 3, length_per_ds_train * 4))
raw_ds_sl_val = raw_ds_sl_val.select(range(length_per_ds_val * 3, length_per_ds_val * 4))
raw_ds_sl_test = raw_ds_sl_test.select(range(length_per_ds_test * 3, length_per_ds_test * 4))

# %% [markdown]
# Finally, we conbine the datasets into one.

# %%
raw_dataset_train = interleave_datasets([raw_ds_en_train, raw_ds_de_train, raw_ds_cz_train, raw_ds_sl_train])
raw_dataset_val = interleave_datasets([raw_ds_en_val, raw_ds_de_val, raw_ds_cz_val, raw_ds_sl_val])
raw_dataset_test = interleave_datasets([raw_ds_en_test, raw_ds_de_test, raw_ds_cz_test, raw_ds_sl_test])

# %%
raw_dataset_train, raw_dataset_val, raw_dataset_test
# Out:
# (Dataset({
#      features: ['Original', 'Paraphrase'],
#      num_rows: 55544
#  }),
#  Dataset({
#      features: ['Original', 'Paraphrase'],
#      num_rows: 9800
#  }),
#  Dataset({
#      features: ['Original', 'Paraphrase'],
#      num_rows: 11532
#  }))

# %% [markdown]
# ## Save data

# %%
DATA_OUTPUT_DIR = "/content/drive/MyDrive/data/"

FILE_NAME_TRAIN = "paraphrases_multilingual_subsampled_train.csv"
FILE_NAME_VAL = "paraphrases_multilingual_subsampled_val.csv"
FILE_NAME_TEST = "paraphrases_multilingual_subsampled_test.csv"

# %%
raw_dataset_train.to_csv(DATA_OUTPUT_DIR + FILE_NAME_TRAIN)
raw_dataset_val.to_csv(DATA_OUTPUT_DIR + FILE_NAME_VAL)
raw_dataset_test.to_csv(DATA_OUTPUT_DIR + FILE_NAME_TEST)
# Out:
# Creating CSV from Arrow format:   0%|          | 0/56 [00:00<?, ?ba/s]
# Creating CSV from Arrow format:   0%|          | 0/10 [00:00<?, ?ba/s]
# Creating CSV from Arrow format:   0%|          | 0/12 [00:00<?, ?ba/s]
# 2088745
