# %% [markdown]
# # Splitting results from a MT5 model for multilanguage paraphrasing using all the data from the monolingual datasets

# %%
enen = 'yawnick/para_crawl_enen'
slsl = 'yawnick/para_crawl_slsl'
cscs = 'yawnick/para_crawl_cscs'
dede = 'yawnick/para_crawl_dede'
dataset = '/content/drive/MyDrive/data/eval_table_multi_all.csv'

# %% [markdown]
# ## Environment Setup

# %% [markdown]
# We need a GPU

# %%
# !nvidia-smi
# Out:
# Thu May 25 15:47:21 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# We install all needed libraries

# %%
# !pip install datasets==2.11.0 transformers==4.28.0 nltk==3.8.1 parascore==1.0.5 sentencepiece==0.1.98
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 72.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 14.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 22.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 18.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 27.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 69.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 14.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# Connect to Google Drive to save the results in the root folder of our Drive at `/content/drive/MyDrive/`.

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## Data Download and Preparation

# %%
from datasets import load_dataset

# %% [markdown]
# We use our own created datasets with paraphrases

# %%
raw_ds_enen = load_dataset(enen, split='test')
raw_ds_slsl = load_dataset(slsl, split='test')
raw_ds_cscs = load_dataset(cscs, split='test')
raw_ds_dede = load_dataset(dede, split='test')
# Out:
# ...
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_enen-1825b56ac7ffdb28/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1. Subsequent calls will reuse this data.
# ...
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/yawnick___csv/yawnick--para_crawl_slsl-e1050e0a2fc9f827/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1. Subsequent calls will reuse this data.
# ...

# %% [markdown]
# We load the evaluated multilanguage dataset

# %%
raw_ds_multi = load_dataset("csv", data_files=dataset, split='train')
raw_ds_multi, raw_ds_enen, raw_ds_slsl, raw_ds_cscs, raw_ds_dede
# Out:
# WARNING:datasets.builder:Found cached dataset csv (/root/.cache/huggingface/datasets/csv/default-f65a437bd5c889fa/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1)
# (Dataset({
#      features: ['Original', 'Reference', 'Paraphrase', 'Parascore'],
#      num_rows: 46128
#  }),
#  Dataset({
#      features: ['Original', 'Paraphrase'],
#      num_rows: 11532
#  }),
#  Dataset({
#      features: ['Original', 'Paraphrase'],
#      num_rows: 11532
#  }),
#  Dataset({
#      features: ['Original', 'Paraphrase'],
#      num_rows: 11532
#  }),
#  Dataset({
#      features: ['Original', 'Paraphrase'],
#      num_rows: 11532
#  }))

# %% [markdown]
# ## Splitting the multilingual dataset

# %% [markdown]
# Initialize the new datasets

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if len(device_name) > 0:
    print("Found GPU at: {}".format(device_name))
else:
    device_name = "/device:CPU:0"
    print("No GPU, using {}.".format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
with tf.device(device_name):
  ds_multi_enen = raw_ds_multi.filter(lambda row: row['Original'] in raw_ds_enen['Original'])
# Out:
# Filter:   0%|          | 0/46128 [00:00<?, ? examples/s]

# %%
with tf.device(device_name):
  ds_multi_slsl = raw_ds_multi.filter(lambda row: row['Original'] in raw_ds_slsl['Original'])
# Out:
# Filter:   0%|          | 0/46128 [00:00<?, ? examples/s]

# %%
with tf.device(device_name):
  ds_multi_cscs = raw_ds_multi.filter(lambda row: row['Original'] in raw_ds_cscs['Original'])
# Out:
# Filter:   0%|          | 0/46128 [00:00<?, ? examples/s]

# %%
with tf.device(device_name):
  ds_multi_dede = raw_ds_multi.filter(lambda row: row['Original'] in raw_ds_dede['Original'])
# Out:
# Filter:   0%|          | 0/46128 [00:00<?, ? examples/s]

# %% [markdown]
# ## Calculate average parascore and save the datasets

# %% [markdown]
# Export the tables

# %%
ds_multi_enen.to_csv('/content/drive/MyDrive/data/eval_table_multi_enen.csv')
ds_multi_slsl.to_csv('/content/drive/MyDrive/data/eval_table_multi_slsl.csv')
ds_multi_cscs.to_csv('/content/drive/MyDrive/data/eval_table_multi_cscs.csv')
ds_multi_dede.to_csv('/content/drive/MyDrive/data/eval_table_multi_dede.csv')
# Out:
# ...
# Creating CSV from Arrow format:   0%|          | 0/12 [00:00<?, ?ba/s]
# 3246936

# %% [markdown]
# Calculate the average scores

# %%
score_enen = sum(ds_multi_enen['Parascore']) / len(ds_multi_enen)
print('Average Parascore EnEn:', score_enen)
# Out:
# Average Parascore EnEn: 0.9391713882367594

# %%
score_slsl = sum(ds_multi_slsl['Parascore']) / len(ds_multi_slsl)
print('Average Parascore SlSl:', score_slsl)
# Out:
# Average Parascore SlSl: 0.9140774907523441

# %%
score_cscs = sum(ds_multi_cscs['Parascore']) / len(ds_multi_cscs)
print('Average Parascore CsCs:', score_cscs)
# Out:
# Average Parascore CsCs: 0.9220988668763804

# %%
score_dede = sum(ds_multi_dede['Parascore']) / len(ds_multi_dede)
print('Average Parascore DeDe:', score_dede)
# Out:
# Average Parascore DeDe: 0.9250622934596161
